# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import networkx as net
import matplotlib.pyplot as plot

# %%
orgchart = net.read_pajek("chapter1/ACME_orgchart.net")
net.draw(orgchart)

# %%
advice = net.read_pajek("chapter1/ACME_advice.net")
net.draw(advice)
